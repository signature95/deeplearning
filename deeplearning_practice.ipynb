# %%
# !pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (2.5.0)
# Collecting tensorflow
#   Downloading tensorflow-2.6.0-cp38-cp38-macosx_10_11_x86_64.whl (199.0 MB)
#      |████████████████████████████████| 199.0 MB 35 kB/s  eta 0:00:01   |▌                               | 2.8 MB 117 kB/s eta 0:27:47     |██████████▎                     | 63.8 MB 1.2 MB/s eta 0:01:49     |████████████▍                   | 76.7 MB 60 kB/s eta 0:33:38     |████████████▊                   | 79.0 MB 66 kB/s eta 0:30:05     |█████████████▍                  | 83.2 MB 297 kB/s eta 0:06:29     |██████████████▏                 | 88.0 MB 337 kB/s eta 0:05:29     |███████████████████████▎        | 144.6 MB 209 kB/s eta 0:04:20     |████████████████████████████    | 174.6 MB 286 kB/s eta 0:01:26     |████████████████████████████▍   | 176.3 MB 209 kB/s eta 0:01:49
# Collecting tensorflow-estimator~=2.6
#   Using cached tensorflow_estimator-2.6.0-py2.py3-none-any.whl (462 kB)
# Requirement already satisfied: flatbuffers~=1.12.0 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.12)
# Requirement already satisfied: termcolor~=1.1.0 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: numpy~=1.19.2 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: astunparse~=1.6.3 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.6.3)
# Collecting grpcio<2.0,>=1.37.0
#   Downloading grpcio-1.41.0-cp38-cp38-macosx_10_10_x86_64.whl (3.9 MB)
#      |████████████████████████████████| 3.9 MB 241 kB/s eta 0:00:01
# Collecting keras~=2.6
#   Using cached keras-2.6.0-py2.py3-none-any.whl (1.3 MB)
# Requirement already satisfied: absl-py~=0.10 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.12.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: six~=1.15.0 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: google-pasta~=0.2 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: wrapt~=1.12.1 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (1.1.2)
# Collecting tensorboard~=2.6
#   Using cached tensorboard-2.6.0-py3-none-any.whl (5.6 MB)
# Requirement already satisfied: opt-einsum~=3.3.0 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: protobuf>=3.9.2 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.17.3)
# Collecting clang~=5.0
#   Using cached clang-5.0.tar.gz (30 kB)
# Requirement already satisfied: wheel~=0.35 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: gast==0.4.0 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: h5py~=3.1.0 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (0.4.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (1.33.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (1.0.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (2.25.1)
# Requirement already satisfied: markdown>=2.6.8 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (3.3.4)
# Requirement already satisfied: setuptools>=41.0.0 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from tensorboard~=2.6->tensorflow) (52.0.0.post20210125)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (4.7.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (1.3.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.6->tensorflow) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (1.26.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard~=2.6->tensorflow) (2.10)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/jeong-giho/opt/anaconda3/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.6->tensorflow) (3.1.1)
# Building wheels for collected packages: clang
#   Building wheel for clang (setup.py) ... done
#   Created wheel for clang: filename=clang-5.0-py3-none-any.whl size=30702 sha256=b807e90db379512abd76c994abafdcec3f856a0a96dc8bacde5d1882fa3a1653
#   Stored in directory: /Users/jeong-giho/Library/Caches/pip/wheels/f1/60/77/22b9b5887bd47801796a856f47650d9789c74dc3161a26d608
# Successfully built clang
# Installing collected packages: grpcio, tensorflow-estimator, tensorboard, keras, clang, tensorflow
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.34.1
#     Uninstalling grpcio-1.34.1:
#       Successfully uninstalled grpcio-1.34.1
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.5.0
#     Uninstalling tensorflow-estimator-2.5.0:
#       Successfully uninstalled tensorflow-estimator-2.5.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.5.0
#     Uninstalling tensorboard-2.5.0:
#       Successfully uninstalled tensorboard-2.5.0
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.5.0
#     Uninstalling tensorflow-2.5.0:
#       Successfully uninstalled tensorflow-2.5.0
# Successfully installed clang-5.0 grpcio-1.41.0 keras-2.6.0 tensorboard-2.6.0 tensorflow-2.6.0 tensorflow-estimator-2.6.0

# %%
# 느낌표를 입력하면, cmd에 직접 입력하고 시행함.

# %%
import pandas as pd

data = pd.read_csv('dataset/ThoraricSurgery(1).csv', encoding = 'utf-8')

# %%
data
# Out:
#       id   DGN  PRE4  PRE5  PRE6 PRE7 PRE8 PRE9 PRE10 PRE11 PRE14 PRE17 PRE19  \
# 0      1  DGN2  2.88  2.16  PRZ1    F    F    F     T     T  OC14     F     F
# 1      2  DGN3  3.40  1.88  PRZ0    F    F    F     F     F  OC12     F     F
# 2      3  DGN3  2.76  2.08  PRZ1    F    F    F     T     F  OC11     F     F
# 3      4  DGN3  3.68  3.04  PRZ0    F    F    F     F     F  OC11     F     F
# 4      5  DGN3  2.44  0.96  PRZ2    F    T    F     T     T  OC11     F     F
# ..   ...   ...   ...   ...   ...  ...  ...  ...   ...   ...   ...   ...   ...
# 465  466  DGN2  3.88  2.12  PRZ1    F    F    F     T     F  OC13     F     F
# 466  467  DGN3  3.76  3.12  PRZ0    F    F    F     F     F  OC11     F     F
# 467  468  DGN3  3.04  2.08  PRZ1    F    F    F     T     F  OC13     F     F
# 468  469  DGN3  1.96  1.68  PRZ1    F    F    F     T     T  OC12     F     F
# 469  470  DGN3  4.72  3.56  PRZ0    F    F    F     F     F  OC12     F     F
#
#     PRE25 PRE30 PRE32  AGE Risk1Yr
# 0       F     T     F   60       F
# 1       F     T     F   51       F
# 2       F     T     F   59       F
# 3       F     F     F   54       F
# 4       F     T     F   73       T
# ..    ...   ...   ...  ...     ...
# 465     F     T     F   63       F
# 466     F     T     F   61       F
# 467     F     F     F   52       F
# 468     F     T     F   79       F
# 469     F     T     F   51       F
#
# [470 rows x 18 columns]

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

import numpy as np
import tensorflow as tf

np.random.seed(3)
tf.random.set_seed(3)

data_set = np.loadtxt('dataset/ThoraricSurgery.csv', delimiter = ',')

# %%
data_set
# Out:
# array([[293.  ,   1.  ,   3.8 , ...,   0.  ,  62.  ,   0.  ],
#        [  1.  ,   2.  ,   2.88, ...,   0.  ,  60.  ,   0.  ],
#        [  8.  ,   2.  ,   3.19, ...,   0.  ,  66.  ,   1.  ],
#        ...,
#        [406.  ,   6.  ,   5.36, ...,   0.  ,  62.  ,   0.  ],
#        [ 25.  ,   8.  ,   4.32, ...,   0.  ,  58.  ,   1.  ],
#        [447.  ,   8.  ,   5.2 , ...,   0.  ,  49.  ,   0.  ]])

# %%
X = data_set[:, 0:17]
y = data_set[:, 17]

# %%
model = Sequential()
model.add(Dense(30, input_dim = 17, activation = 'relu'))
model.add(Dense(1, activation = 'sigmoid'))

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs = 100, batch_size = 10)
# Out:
# Epoch 1/100
# 47/47 [==============================] - 1s 2ms/step - loss: 0.6482 - accuracy: 0.8128
# Epoch 2/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4890 - accuracy: 0.8468
# Epoch 3/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4416 - accuracy: 0.8511
# Epoch 4/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4863 - accuracy: 0.8489
# Epoch 5/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4430 - accuracy: 0.8532
# Epoch 6/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4303 - accuracy: 0.8532
# Epoch 7/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4421 - accuracy: 0.8511
# Epoch 8/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4363 - accuracy: 0.8489
# Epoch 9/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4165 - accuracy: 0.8489
# Epoch 10/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4317 - accuracy: 0.8489
# Epoch 11/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4458 - accuracy: 0.8489
# Epoch 12/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4384 - accuracy: 0.8532
# Epoch 13/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4651 - accuracy: 0.8532
# Epoch 14/100
# 47/47 [==============================] - 0s 5ms/step - loss: 0.4475 - accuracy: 0.8319
# Epoch 15/100
# 47/47 [==============================] - 0s 10ms/step - loss: 0.4934 - accuracy: 0.8255
# Epoch 16/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4472 - accuracy: 0.8447
# Epoch 17/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4747 - accuracy: 0.8383
# Epoch 18/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4488 - accuracy: 0.8468
# Epoch 19/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4407 - accuracy: 0.8511
# Epoch 20/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4380 - accuracy: 0.8511
# Epoch 21/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4331 - accuracy: 0.8532
# Epoch 22/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4242 - accuracy: 0.8511
# Epoch 23/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4183 - accuracy: 0.8532
# Epoch 24/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4303 - accuracy: 0.8489
# Epoch 25/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4246 - accuracy: 0.8511
# Epoch 26/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4335 - accuracy: 0.8532
# Epoch 27/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4492 - accuracy: 0.8383
# Epoch 28/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4241 - accuracy: 0.8532
# Epoch 29/100
# 47/47 [==============================] - 0s 6ms/step - loss: 0.4212 - accuracy: 0.8532
# Epoch 30/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4136 - accuracy: 0.8511
# Epoch 31/100
# 47/47 [==============================] - 0s 4ms/step - loss: 0.4389 - accuracy: 0.8511
# Epoch 32/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4188 - accuracy: 0.8553
# Epoch 33/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4428 - accuracy: 0.8532
# Epoch 34/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4103 - accuracy: 0.8489
# Epoch 35/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4178 - accuracy: 0.8489
# Epoch 36/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4136 - accuracy: 0.8532
# Epoch 37/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4429 - accuracy: 0.8511
# Epoch 38/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4258 - accuracy: 0.8489
# Epoch 39/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4714 - accuracy: 0.8319
# Epoch 40/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4041 - accuracy: 0.8574
# Epoch 41/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4210 - accuracy: 0.8511
# Epoch 42/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4418 - accuracy: 0.8447
# Epoch 43/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4096 - accuracy: 0.8511
# Epoch 44/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4032 - accuracy: 0.8511
# Epoch 45/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4067 - accuracy: 0.8532
# Epoch 46/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4030 - accuracy: 0.8532
# Epoch 47/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4132 - accuracy: 0.8447
# Epoch 48/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4026 - accuracy: 0.8532
# Epoch 49/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4082 - accuracy: 0.8511
# Epoch 50/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4097 - accuracy: 0.8511
# Epoch 51/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4124 - accuracy: 0.8532
# Epoch 52/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3972 - accuracy: 0.8553
# Epoch 53/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4128 - accuracy: 0.8489
# Epoch 54/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4073 - accuracy: 0.8468
# Epoch 55/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4110 - accuracy: 0.8532
# Epoch 56/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3921 - accuracy: 0.8532
# Epoch 57/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4091 - accuracy: 0.8532
# Epoch 58/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3995 - accuracy: 0.8574
# Epoch 59/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3985 - accuracy: 0.8532
# Epoch 60/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3899 - accuracy: 0.8574
# Epoch 61/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4041 - accuracy: 0.8553
# Epoch 62/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4246 - accuracy: 0.8468
# Epoch 63/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4068 - accuracy: 0.8532
# Epoch 64/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4318 - accuracy: 0.8511
# Epoch 65/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3902 - accuracy: 0.8553
# Epoch 66/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4312 - accuracy: 0.8511
# Epoch 67/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4164 - accuracy: 0.8489
# Epoch 68/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4090 - accuracy: 0.8511
# Epoch 69/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4020 - accuracy: 0.8511
# Epoch 70/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.3986 - accuracy: 0.8574
# Epoch 71/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4027 - accuracy: 0.8511
# Epoch 72/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4196 - accuracy: 0.8340
# Epoch 73/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4019 - accuracy: 0.8532
# Epoch 74/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3907 - accuracy: 0.8553
# Epoch 75/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3890 - accuracy: 0.8553
# Epoch 76/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4077 - accuracy: 0.8553
# Epoch 77/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4178 - accuracy: 0.8426
# Epoch 78/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4080 - accuracy: 0.8553
# Epoch 79/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4148 - accuracy: 0.8426
# Epoch 80/100
# 47/47 [==============================] - 0s 3ms/step - loss: 0.4019 - accuracy: 0.8468
# Epoch 81/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4057 - accuracy: 0.8532
# Epoch 82/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4184 - accuracy: 0.8489
# Epoch 83/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3944 - accuracy: 0.8532
# Epoch 84/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4345 - accuracy: 0.8468
# Epoch 85/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4050 - accuracy: 0.8489
# Epoch 86/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3922 - accuracy: 0.8489
# Epoch 87/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3976 - accuracy: 0.8511
# Epoch 88/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3966 - accuracy: 0.8468
# Epoch 89/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3886 - accuracy: 0.8468
# Epoch 90/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3965 - accuracy: 0.8596
# Epoch 91/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4220 - accuracy: 0.8532
# Epoch 92/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.4198 - accuracy: 0.8489
# Epoch 93/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3953 - accuracy: 0.8511
# Epoch 94/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3871 - accuracy: 0.8489
# Epoch 95/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3864 - accuracy: 0.8574
# Epoch 96/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4229 - accuracy: 0.8426
# Epoch 97/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4149 - accuracy: 0.8447
# Epoch 98/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.3857 - accuracy: 0.8596
# Epoch 99/100
# 47/47 [==============================] - 0s 1ms/step - loss: 0.4051 - accuracy: 0.8532
# Epoch 100/100
# 47/47 [==============================] - 0s 2ms/step - loss: 0.3832 - accuracy: 0.8468
